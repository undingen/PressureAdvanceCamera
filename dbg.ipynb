# %%
image_path = "test_data/gold/gray50_5,6.jpg"
debug = True

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import cv2
import matplotlib.pyplot as plt

# %%
if 0:
    from segment_image import SegmentImage
    segmenter = SegmentImage()
    seg_img = segmenter.segment(image_path)
else:
    image_path = image_path.replace(".jpg", "_out.png")
    seg_img = cv2.imread(image_path, cv2.IMREAD_UNCHANGED)

# %%
from retrieve_rect import RetrieveRect
retrieve_rect = RetrieveRect(debug=debug)
rect_img = retrieve_rect.process_image(seg_img)
#plt.imshow(res)
#plt.show()

# %%
from line_analyzer import LineAnalyzer
analyzer = LineAnalyzer(rect_img, debug=debug)
smoothest = analyzer.get_smoothest_lines()
print("Top 5 smoothest lines:", smoothest)
# Out:
# Top 5 smoothest lines: [(6, 1.0980440082779606, 1.6310414338655497), (5, 1.210864738404356, 1.820228011016651), (4, 1.100700605269403, 2.3236364994919425), (8, 1.8245279668172043, 2.5163309264246028), (7, 1.1553016313394975, 2.5909264477301797)]
